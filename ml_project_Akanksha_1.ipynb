# %% [markdown]
# # Course Project: Analyzing Gun Violence incidents

# %% [markdown]
# ### CS 6316 Machine Learning - Department of Computer Science - University of Virginia

# %% [markdown]
# ---
# ## DATA OVERVIEW

# %%
# Import some common packages
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# to make this notebook's output stable across runs
np.random.seed(42)

DATA_PATH = '.'

def load_data(data_path=DATA_PATH):
    csv_path = os.path.join(data_path, "gun-violence-data_01-2013_03-2018.csv")
    return pd.read_csv(csv_path)

all_data = load_data()

# %%
# Start with a subset that only contains Virginia events
VA_data = all_data.loc[all_data['state']=='Virginia']
VA_data = VA_data.reset_index()
VA_data.head()
# Out:
#    index  incident_id       date     state  city_or_county  \
# 0     79       486611  5/18/2013  Virginia        Victoria
# 1     86       486998  5/25/2013  Virginia         Hampton
# 2     93       487271   6/2/2013  Virginia  Virginia Beach
# 3    105       488505  6/21/2013  Virginia         Norfolk
# 4    113       489129  6/23/2013  Virginia  Virginia Beach
#
#                          address  n_killed  n_injured  \
# 0           2073 Pleasant Oak Rd         0          4
# 1   1900 block of Coliseum Drive         1          4
# 2    4000 block of Roebling Lane         0          7
# 3           1225 Tidewater Drive         0          6
# 4  4600 block of Columbus Street         1          4
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/486611
# 1  http://www.gunviolencearchive.org/incident/486998
# 2  http://www.gunviolencearchive.org/incident/487271
# 3  http://www.gunviolencearchive.org/incident/488505
# 4  http://www.gunviolencearchive.org/incident/489129
#
#                                           source_url          ...           \
# 0  http://southsidemessenger.com/shooter-accepts-...          ...
# 1  http://wavy.com/2014/04/15/charges-could-be-dr...          ...
# 2  http://articles.dailypress.com/2013-06-02/news...          ...
# 3  http://www.13newsnow.com/story/news/2014/09/09...          ...
# 4  http://www.13newsnow.com/story/news/2014/09/09...          ...
#
#                                    participant_age  \
# 0                                            4::22
# 1  0::16||1::14||2::16||3::17||4::18||5::15||6::17
# 2                                              NaN
# 3         0::16||1::17||6::25||7::20||8::20||9::24
# 4                                            0::25
#
#                                participant_age_group  \
# 0  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 1  0::Teen 12-17||1::Teen 12-17||2::Teen 12-17||3...
# 2  3::Adult 18+||4::Adult 18+||5::Adult 18+||6::A...
# 3  0::Teen 12-17||1::Teen 12-17||6::Adult 18+||7:...
# 4                                       0::Adult 18+
#
#                                   participant_gender  \
# 0  0::Male||1::Male||2::Male||3::Male||4::Male||5...
# 1                          0::Male||5::Male||6::Male
# 2  3::Male||4::Male||5::Male||6::Male||8::Male||9...
# 3                 6::Male||7::Male||8::Male||9::Male
# 4                                            0::Male
#
#                                     participant_name participant_relationship  \
# 0  0::Stan Woods||1::Dequan Jones||2::Treyvious G...                      NaN
# 1  0::Ralphael Davis Jr||5::Ryan Taybron||6::Eric...                      NaN
# 2                                                NaN                      NaN
# 3  6::Kyle Edward Thornton||7::Darren Lamont Robe...                      NaN
# 4                                0::Rashawn R. Dukes                      NaN
#
#                                   participant_status  \
# 0  0::Injured||1::Injured||2::Injured||3::Injured...
# 1  0::Killed||1::Injured||2::Injured||3::Injured|...
# 2  0::Injured||1::Injured||2::Injured||3::Injured...
# 3  0::Injured||1::Injured||2::Injured||3::Injured...
# 4  0::Killed||1::Injured||2::Injured||3::Injured|...
#
#                                     participant_type  \
# 0  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 3  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 4  0::Victim||1::Victim||2::Victim||3::Victim||4:...
#
#                                              sources  state_house_district  \
# 0  http://www.nbc12.com/story/22291717/man-wanted...                  75.0
# 1  http://articles.dailypress.com/2013-05-28/news...                  92.0
# 2  http://articles.dailypress.com/2013-06-02/news...                  82.0
# 3  http://pilotonline.com/news/local/crime/police...                  89.0
# 4  http://www.13newsnow.com/story/news/2014/09/09...                  85.0
#
#   state_senate_district
# 0                  15.0
# 1                   2.0
# 2                   7.0
# 3                   5.0
# 4                   7.0
#
# [5 rows x 30 columns]

# %%
VA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5949 entries, 0 to 5948
# Data columns (total 30 columns):
# index                          5949 non-null int64
# incident_id                    5949 non-null int64
# date                           5949 non-null object
# state                          5949 non-null object
# city_or_county                 5949 non-null object
# address                        5706 non-null object
# n_killed                       5949 non-null int64
# n_injured                      5949 non-null int64
# incident_url                   5949 non-null object
# source_url                     5941 non-null object
# incident_url_fields_missing    5949 non-null bool
# congressional_district         5656 non-null float64
# gun_stolen                     3000 non-null object
# gun_type                       3002 non-null object
# incident_characteristics       5932 non-null object
# latitude                       5678 non-null float64
# location_description           1076 non-null object
# longitude                      5678 non-null float64
# n_guns_involved                3002 non-null float64
# notes                          5295 non-null object
# participant_age                3318 non-null object
# participant_age_group          5004 non-null object
# participant_gender             5109 non-null object
# participant_name               2638 non-null object
# participant_relationship       383 non-null object
# participant_status             5407 non-null object
# participant_type               5431 non-null object
# sources                        5940 non-null object
# state_house_district           5654 non-null float64
# state_senate_district          5654 non-null float64
# dtypes: bool(1), float64(6), int64(4), object(19)
# memory usage: 1.3+ MB

# %%
VA_data.describe()
# Out:
#                index   incident_id     n_killed    n_injured  \
# count    5949.000000  5.949000e+03  5949.000000  5949.000000
# mean   118988.595898  5.535545e+05     0.245251     0.599428
# std     67693.146593  2.864360e+05     0.502043     0.725002
# min        79.000000  9.212200e+04     0.000000     0.000000
# 25%     61225.000000  3.129690e+05     0.000000     0.000000
# 50%    121107.000000  5.459920e+05     0.000000     1.000000
# 75%    174258.000000  7.932450e+05     0.000000     1.000000
# max    239591.000000  1.083347e+06     6.000000    10.000000
#
#        congressional_district     latitude    longitude  n_guns_involved  \
# count             5656.000000  5678.000000  5678.000000      3002.000000
# mean                 4.337341    37.361878   -77.431925         1.199867
# std                  2.420746     0.608199     1.336288         1.732347
# min                  1.000000    36.090000   -88.463100         1.000000
# 25%                  3.000000    36.875525   -77.521350         1.000000
# 50%                  3.000000    37.232900   -77.361950         1.000000
# 75%                  6.000000    37.549100   -76.378250         1.000000
# max                 11.000000    39.341300   -75.379500        50.000000
#
#        state_house_district  state_senate_district
# count           5654.000000            5654.000000
# mean              64.054298              13.880615
# std               28.399610              10.054745
# min                1.000000               1.000000
# 25%               49.000000               5.000000
# 50%               71.000000              11.000000
# 75%               89.000000              20.000000
# max              100.000000              40.000000

# %% [markdown]
# We can see there are some missing values. And some columns may need to be preprocessed before we actually use it, such as "participant_status", whose value is like "0::Injured, Unharmed, Arrested||1::Unharmed, Arrested||2::Killed".

# %% [markdown]
# ---
# ## DATA PREPROCESSING

# %% [raw]
# Actions on columns:
# incident_id                    drop
# date
# state
# city_or_county
# address                        drop
# n_killed
# n_injured
# incident_url                   drop
# source_url                     drop
# incident_url_fields_missing    drop
# congressional_district
# gun_stolen                     3000 too many missing fields, drop (at least for now)
# gun_type                       3002 too many missing fields, drop (at least for now)
# incident_characteristics       Multi-valued field, separated by '||'
# latitude
# location_description           drop
# longitude
# n_guns_involved                3002 too many missing fields, drop (at least for now)
# notes                          drop. Needs NLP.
# participant_age                3318 drop. Multi-valued field, separated by '||'. Too many missing fields, and we use "participant_age_group"
# participant_age_group          5004 Multi-valued field, separated by '||'. Values can be: Child 0-11, Teen 12-17, Adult 18+.
# participant_gender             5109 Multi-valued field, separated by '||'. Values can be: Male, Female
# participant_name               2638 drop
# participant_relationship       383 drop
# participant_status             5407 Multi-valued field, separated by '||'. For each value, there can be multiple status that are separated by ','.
# participant_type               5431 Multi-valued field, separated by '||'
# sources                        drop
# state_house_district           5654 non-null float64
# state_senate_district          5654 non-null float64

# %%
# You might want to use the following package
from sklearn.model_selection import train_test_split
from pandas.plotting import scatter_matrix # optional
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from copy import deepcopy

# Drop
processed_data = deepcopy(VA_data)
dropped_columns = ['incident_id', 'address', 'incident_url', 'source_url', 'incident_url_fields_missing', 'gun_stolen', 'gun_type', 'location_description', 'n_guns_involved', 'notes', 'participant_age', 'participant_name', 'participant_relationship', 'sources']

processed_data = processed_data.drop(dropped_columns, axis=1)

# %% [markdown]
# The following codes tries to get some insight about the columns.

# %%
#extract month and year from date
processed_data['month'] = pd.DatetimeIndex(processed_data['date']).month
processed_data['year'] = pd.DatetimeIndex(processed_data['date']).year

# %%
def getColumnDict(column_name):
    column = processed_data[column_name]
    temp_dict = {}
    for line in column:
        s = str(line).replace('||', '|')
        arr = s.split('|')
        for e in arr:
            e = e.replace('::', ':')
            if e.find(':') != -1:
                e = e[e.find(':')+1:]
            if e not in temp_dict:
                #print(e)
                temp_dict[e] = 1
            else:
                temp_dict[e] += 1
    temp_dict = sorted(temp_dict.items(), key=lambda d: d[1], reverse=True)
    return temp_dict

# %%
chara_dict = getColumnDict('incident_characteristics')
print(chara_dict)
# Out:
# [('Shot - Wounded/Injured', 2908), ('Shot - Dead (murder, accidental, suicide)', 1294), ('Shots Fired - No Injuries', 791), ('Non-Shooting Incident', 665), ('Armed robbery with injury/death and/or evidence of DGU found', 546), ('Officer Involved Incident', 353), ('Possession of gun by felon or prohibited person', 309), ('Institution/Group/Business', 297), ('Brandishing/flourishing/open carry/lost/found', 290), ('Home Invasion', 283), ('Domestic Violence', 274), ('Drive-by (car to street, car to car)', 235), ('Drug involvement', 207), ('Accidental Shooting', 206), ('Possession (gun(s) found during commission of other crimes)', 191), ('ATF/LE Confiscation/Raid/Arrest', 161), ('Home Invasion - No death or injury', 154), ('Accidental/Negligent Discharge', 141), ('Accidental Shooting - Injury', 137), ('Suicide^', 136), ('Car-jacking', 108), ('TSA Action', 106), ('Defensive Use', 104), ('School Incident', 104), ('Gun at school, no death/injury - elementary/secondary school', 85), ('Officer Involved Shooting - subject/suspect/perpetrator killed', 84), ('Bar/club incident - in or around establishment', 76), ('Murder/Suicide', 71), ('Home Invasion - Resident injured', 70), ('Officer Involved Shooting - subject/suspect/perpetrator shot', 69), ('Gun(s) stolen from owner', 64), ('Officer Involved Shooting - Shots fired, no injury', 60), ('Officer Involved Incident - Weapon involved but no shots fired', 59), ('Pistol-whipping', 58), ('Child Involved Incident', 58), ('BB/Pellet/Replica gun', 58), ('Stolen/Illegally owned gun{s} recovered during arrest/warrant', 57), ('Kidnapping/abductions/hostage', 54), ('Officer Involved Shooting - subject/suspect/perpetrator surrender at standoff', 53), ('Self-Inflicted (not suicide or suicide attempt - NO PERP)', 52), ('Non-Aggression Incident', 46), (' No GV Incident Occurred Onsite', 45), ('Gang involvement', 43), ('Under the influence of alcohol or drugs (only applies to the subject/suspect/perpetrator )', 43), ('Mass Shooting (4+ victims injured or killed excluding the subject/suspect/perpetrator, one location)', 42), ('Accidental Shooting - Death', 42), ('Road rage', 39), ('Defensive Use - Crime occurs, victim shoots subject/suspect/perpetrator', 39), ('Implied Weapon', 36), ('Shootout (where VENN diagram of shooters and victims overlap)', 36), ('Shots fired, no action (reported, no evidence found)', 34), ('Defensive Use - Victim stops crime', 31), ('House party', 29), ('Officer Involved Shooting - subject/suspect/perpetrator suicide at standoff', 28), ('Officer Involved Shooting - Officer shot', 27), ('Home Invasion - Resident killed', 25), ('Playing with gun', 25), ('Home Invasion - subject/suspect/perpetrator injured', 24), ('Assault weapon (AR-15, AK-47, and ALL variants defined by law enforcement)', 22), ('Gun shop robbery or burglary', 20), ('Criminal act with stolen gun', 20), ('Child injured (not child shooter)', 20), ('Animal shot/killed', 18), ('nan', 17), ('Cleaning gun', 17), ('Home Invasion - subject/suspect/perpetrator killed', 17), ('Suicide - Attempt', 16), ('Child picked up & fired gun', 15), ('Hunting accident', 12), ('Accidental Shooting at a Business', 12), ('Unlawful purchase/sale', 12), ('Sex crime involving firearm', 11), ('Attempted Murder/Suicide (one variable unsuccessful)', 11), ('Child injured by child', 10), ('Officer Involved Shooting - Officer killed', 9), ('Gun at school, no death/injury - university/college', 9), ('Gun range/gun shop/gun show shooting', 8), ('Defensive Use - Shots fired, no injury/death', 8), ('Defensive Use - WITHOUT a gun', 8), ('Defensive Use - Stand Your Ground/Castle Doctrine established', 7), ('Defensive Use - Good Samaritan/Third Party', 6), ('Child with gun - no shots fired', 6), ('Child killed (not child shooter)', 6), ('Workplace shooting (disgruntled employee)', 5), ('Child killed self', 5), ('Officer Involved Shooting - Bystander shot', 5), ('Officer Involved Shooting - Accidental discharge - no injury required', 5), ('Child injured self ...

# %%
age_group_dict = getColumnDict('participant_age_group')
print(age_group_dict)
# Out:
# [('Adult 18+', 7598), ('nan', 945), ('Teen 12-17', 712), ('Child 0-11', 125)]

# %%
gender_dict = getColumnDict('participant_gender')
print(gender_dict)
# Out:
# [('Male', 7735), ('Female', 1016), ('nan', 840)]

# %%
status_dict = getColumnDict('participant_status')
print(status_dict)
# Out:
# [('Injured', 3474), ('Unharmed', 2364), ('Unharmed, Arrested', 1977), ('Killed', 1456), ('nan', 542), ('Injured, Arrested', 87), ('Arrested', 85), ('Injured, Unharmed', 3), ('Killed, Arrested', 2), ('Killed, Unharmed', 1), ('Injured, Unharmed, Arrested', 1), ('Killed, Unharmed, Arrested', 1)]

# %%
type_dict = getColumnDict('participant_type')
print(type_dict)
# Out:
# [('Victim', 5178), ('Subject-Suspect', 4528), ('nan', 518)]

# %% [markdown]
# We can see there is a small portion of bad data.

# %% [markdown]
# we cannot skip these features as these contain a lot of vital information. So we have decided to extract useful information and add below columns in our dataframe:
#
# 1. participant_age_group - There are only 3 categories of participants so we will count the number of participants belonging to these groups:
#     a. child_participants - '0-11' years old
#     b. teen_participants - '12-17' years old
#     c. adult_participants - '18+' years old
#
# 2. participant_gender - We can count the number of males and females involved in an incident to get the gender ratio.
# - no of male
# -  no of females
#
# 3. participant_status -> We can count the number of participants in each category. we already have n_killed and n_injured columns.
# - n_unharmed,
# - n_arrested,
# - If someone is arrested: For our problem of predicting gun-violence, we ignore if suspect was arrested unharmed or injured.
#
# 4. participant_type - We can get an idea of number of victims involved and number of suspects identified.
# - victims involved
# - suspects identified
#
# 5. incident_characteristics
# Shot
# non-shooting
# home invasion
# domestic violence

# %%
processed_data.head()
# Out:
#    index       date     state  city_or_county  n_killed  n_injured  \
# 0     79  5/18/2013  Virginia        Victoria         0          4
# 1     86  5/25/2013  Virginia         Hampton         1          4
# 2     93   6/2/2013  Virginia  Virginia Beach         0          7
# 3    105  6/21/2013  Virginia         Norfolk         0          6
# 4    113  6/23/2013  Virginia  Virginia Beach         1          4
#
#    congressional_district                           incident_characteristics  \
# 0                     5.0  Shot - Wounded/Injured||Drive-by (car to stree...
# 1                     3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 2                     2.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 3                     3.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 4                     2.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
#
#    latitude  longitude                              participant_age_group  \
# 0   37.0177   -78.1562  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 1   37.0377   -76.3859  0::Teen 12-17||1::Teen 12-17||2::Teen 12-17||3...
# 2   36.8459   -76.1171  3::Adult 18+||4::Adult 18+||5::Adult 18+||6::A...
# 3   36.8571   -76.2735  0::Teen 12-17||1::Teen 12-17||6::Adult 18+||7:...
# 4   36.8410   -76.1371                                       0::Adult 18+
#
#                                   participant_gender  \
# 0  0::Male||1::Male||2::Male||3::Male||4::Male||5...
# 1                          0::Male||5::Male||6::Male
# 2  3::Male||4::Male||5::Male||6::Male||8::Male||9...
# 3                 6::Male||7::Male||8::Male||9::Male
# 4                                            0::Male
#
#                                   participant_status  \
# 0  0::Injured||1::Injured||2::Injured||3::Injured...
# 1  0::Killed||1::Injured||2::Injured||3::Injured|...
# 2  0::Injured||1::Injured||2::Injured||3::Injured...
# 3  0::Injured||1::Injured||2::Injured||3::Injured...
# 4  0::Killed||1::Injured||2::Injured||3::Injured|...
#
#                                     participant_type  state_house_district  \
# 0  0::Victim||1::Victim||2::Victim||3::Victim||4:...                  75.0
# 1  0::Victim||1::Victim||2::Victim||3::Victim||4:...                  92.0
# 2  0::Victim||1::Victim||2::Victim||3::Victim||4:...                  82.0
# 3  0::Victim||1::Victim||2::Victim||3::Victim||4:...                  89.0
# 4  0::Victim||1::Victim||2::Victim||3::Victim||4:...                  85.0
#
#    state_senate_district  month  year
# 0                   15.0      5  2013
# 1                    2.0      5  2013
# 2                    7.0      6  2013
# 3                    5.0      6  2013
# 4                    7.0      6  2013

# %%
# add new columns to our dataframe
new_columns = [['child_participants', 'teen_participants', 'adult_participants'],
              ['male_participants', 'female_participants'],
              ['arrested_participants', 'injured_participants', 'killed_participants', 'unharmed_participants'],
              ['victims_involved', 'suspects_identified']];

for item in new_columns:
    for col in item:
        processed_data[col] = 0;

processed_data.head()
# Out:
#    index       date     state  city_or_county  n_killed  n_injured  \
# 0     79  5/18/2013  Virginia        Victoria         0          4
# 1     86  5/25/2013  Virginia         Hampton         1          4
# 2     93   6/2/2013  Virginia  Virginia Beach         0          7
# 3    105  6/21/2013  Virginia         Norfolk         0          6
# 4    113  6/23/2013  Virginia  Virginia Beach         1          4
#
#    congressional_district                           incident_characteristics  \
# 0                     5.0  Shot - Wounded/Injured||Drive-by (car to stree...
# 1                     3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 2                     2.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 3                     3.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 4                     2.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
#
#    latitude  longitude         ...          teen_participants  \
# 0   37.0177   -78.1562         ...                          0
# 1   37.0377   -76.3859         ...                          0
# 2   36.8459   -76.1171         ...                          0
# 3   36.8571   -76.2735         ...                          0
# 4   36.8410   -76.1371         ...                          0
#
#   adult_participants male_participants female_participants  \
# 0                  0                 0                   0
# 1                  0                 0                   0
# 2                  0                 0                   0
# 3                  0                 0                   0
# 4                  0                 0                   0
#
#    arrested_participants  injured_participants  killed_participants  \
# 0                      0                     0                    0
# 1                      0                     0                    0
# 2                      0                     0                    0
# 3                      0                     0                    0
# 4                      0                     0                    0
#
#    unharmed_participants  victims_involved  suspects_identified
# 0                      0                 0                    0
# 1                      0                 0                    0
# 2                      0                 0                    0
# 3                      0                 0                    0
# 4                      0                 0                    0
#
# [5 rows x 29 columns]

# %%
# Extract for each row: from column_name_list[i] extract info_list[i] values.
# Return list of dictionaries where dictionary at list[i] corresponds to column_name_list[i].
# 5::Injured||6::Unharmed||7::Unharmed, Arrested||8::Unharmed, Arrested||9::Unharmed, Arrested
processed_data_new = processed_data.copy()

new_columns = [['child_participants', 'teen_participants', 'adult_participants'],
              ['male_participants', 'female_participants'],
              ['arrested_participants', 'injured_participants', 'killed_participants', 'unharmed_participants'],
              ['victims_involved', 'suspects_identified']];

info_list = [
               ['Child', 'Teen','Adult'],
               ['Male', 'Female'],
               ['Arrested', 'Injured', 'Killed', 'Unharmed'],
               ['Victim', 'Suspect']
            ];

def extractInfoFromColumns(row_index, column_name_list, info_list, new_columns):
    
    temp_dict = {}
    for i in range(len(column_name_list)):
        column_name = column_name_list[i]
        line = processed_data.at[row_index,column_name]        
        #print(line)
        #break
        s = str(line).replace('||', '|')
        arr = s.split('|')
        for e in arr:
            e = e.replace('::', ':')
            if e.find(':') != -1:
                e = e[e.find(':')+1:]
            
            if ", Arrested" in e:
                e= 'Arrested'
            
            #print(e)
            item = info_list[i]                
            for j in range(len(item)):
                #print(item[j])
                if item[j] in e:
                    new_col = new_columns[i][j]
                    if new_col not in temp_dict:
                        #print(e)
                        temp_dict[new_col] = 1
                    else:
                        temp_dict[new_col] += 1
                #else:
                    #print('not found '+item[j])
    #print(temp_dict)
    for key, value in temp_dict.items():
        processed_data_new.at[row_index,key] = value
        
cols = ['participant_age_group', 'participant_gender', 'participant_status', 'participant_type']
for i in range(len(processed_data)):
    extractInfoFromColumns(i, cols, info_list, new_columns)

    
processed_data_new.head()
# Out:
#    index       date     state  city_or_county  n_killed  n_injured  \
# 0     79  5/18/2013  Virginia        Victoria         0          4
# 1     86  5/25/2013  Virginia         Hampton         1          4
# 2     93   6/2/2013  Virginia  Virginia Beach         0          7
# 3    105  6/21/2013  Virginia         Norfolk         0          6
# 4    113  6/23/2013  Virginia  Virginia Beach         1          4
#
#    congressional_district                           incident_characteristics  \
# 0                     5.0  Shot - Wounded/Injured||Drive-by (car to stree...
# 1                     3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 2                     2.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 3                     3.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 4                     2.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
#
#    latitude  longitude         ...          teen_participants  \
# 0   37.0177   -78.1562         ...                          0
# 1   37.0377   -76.3859         ...                          6
# 2   36.8459   -76.1171         ...                          0
# 3   36.8571   -76.2735         ...                          2
# 4   36.8410   -76.1371         ...                          0
#
#   adult_participants male_participants female_participants  \
# 0                  6                 6                   0
# 1                  1                 3                   0
# 2                  7                 6                   0
# 3                  4                 4                   0
# 4                  1                 1                   0
#
#    arrested_participants  injured_participants  killed_participants  \
# 0                      2                     4                    0
# 1                      0                     4                    1
# 2                      0                     7                    0
# 3                      3                     6                    0
# 4                      0                     4                    1
#
#    unharmed_participants  victims_involved  suspects_identified
# 0                      0                 4                    2
# 1                      0                 5                    2
# 2                      6                 4                    6
# 3                      1                 6                    4
# 4                      0                 5                    0
#
# [5 rows x 29 columns]

# %%
#dropping the original columns after parsing
processed_data_new = processed_data_new.drop('incident_characteristics', axis=1)
processed_data_new = processed_data_new.drop('participant_age_group', axis=1)
processed_data_new = processed_data_new.drop('participant_gender', axis=1)
processed_data_new = processed_data_new.drop('participant_status', axis=1)
processed_data_new = processed_data_new.drop('participant_type', axis=1)
processed_data_new = processed_data_new.drop('killed_participants', axis=1) #same as n_killed
processed_data_new = processed_data_new.drop('injured_participants', axis=1) #same as n_injured
processed_data_new = processed_data_new.drop('date', axis=1)
processed_data_new = processed_data_new.drop('state', axis=1) #since state is virginia

# %%
processed_data_new.head()
# Out:
#    index  city_or_county  n_killed  n_injured  congressional_district  \
# 0     79        Victoria         0          4                     5.0
# 1     86         Hampton         1          4                     3.0
# 2     93  Virginia Beach         0          7                     2.0
# 3    105         Norfolk         0          6                     3.0
# 4    113  Virginia Beach         1          4                     2.0
#
#    latitude  longitude  state_house_district  state_senate_district  month  \
# 0   37.0177   -78.1562                  75.0                   15.0      5
# 1   37.0377   -76.3859                  92.0                    2.0      5
# 2   36.8459   -76.1171                  82.0                    7.0      6
# 3   36.8571   -76.2735                  89.0                    5.0      6
# 4   36.8410   -76.1371                  85.0                    7.0      6
#
#    year  child_participants  teen_participants  adult_participants  \
# 0  2013                   0                  0                   6
# 1  2013                   0                  6                   1
# 2  2013                   0                  0                   7
# 3  2013                   0                  2                   4
# 4  2013                   0                  0                   1
#
#    male_participants  female_participants  arrested_participants  \
# 0                  6                    0                      2
# 1                  3                    0                      0
# 2                  6                    0                      0
# 3                  4                    0                      3
# 4                  1                    0                      0
#
#    unharmed_participants  victims_involved  suspects_identified
# 0                      0                 4                    2
# 1                      0                 5                    2
# 2                      6                 4                    6
# 3                      1                 6                    4
# 4                      0                 5                    0

# %%
processed_data_new["city_or_county"].value_counts()

#maximum incidents have occured in Richmond and Norfolk cities while no of incidents in Charlottesville are 76.
# Out:
# Richmond                 994
# Norfolk                  622
# Newport News             536
# Hampton                  360
# Virginia Beach           289
# Portsmouth               271
# Roanoke                  227
# Danville                 151
# Chesapeake               137
# Petersburg               129
# Chesterfield             102
# Lynchburg                100
# Henrico                   89
# Henrico (county)          85
# Alexandria                84
# Woodbridge                78
# Suffolk                   78
# Charlottesville           76
# Arlington                 63
# Hopewell                  54
# Fredericksburg            45
# Manassas                  43
# Stafford                  39
# Chesterfield (county)     32
# Williamsburg              30
# Martinsville              29
# Waynesboro                27
# Dulles                    23
# Falls Church              22
# Sterling                  19
#                         ...
# Powhatan (county)          1
# Dungannon                  1
# Gloucester County          1
# Roseland                   1
# Roanoke County             1
# Austinville                1
# Mc Lean (McLean)           1
# Fort Valley                1
# Lawrenceville              1
# Appalachia                 1
# Leesburg (Lucketts)        1
# Pulaski County             1
# Meherrin                   1
# Appalachia (Exeter)        1
# Deskins                    1
# Tazewell (county)          1
# Courtland                  1
# Grafton                    1
# New Kent                   1
# Stafford County            1
# Bent Mountain              1
# Hamilton                   1
# Barboursville              1
# Reva                       1
# King William               1
# Ettrick                    1
# Glen Lyn                   1
# Madison County             1
# Garden Creek               1
# Mc Dowell                  1
# Name: city_or_county, Length: 445, dtype: int64

# %%
processed_data_new["year"].value_counts()

#most of our data is recent and we have a good amount of data for each year.
# Out:
# 2016    1578
# 2017    1473
# 2015    1326
# 2014    1273
# 2018     293
# 2013       6
# Name: year, dtype: int64

# %%
#checking for null values
print(processed_data_new.isnull().sum())
# Out:
# index                       0
# city_or_county              0
# n_killed                    0
# n_injured                   0
# congressional_district    293
# latitude                  271
# longitude                 271
# state_house_district      295
# state_senate_district     295
# month                       0
# year                        0
# child_participants          0
# teen_participants           0
# adult_participants          0
# male_participants           0
# female_participants         0
# arrested_participants       0
# unharmed_participants       0
# victims_involved            0
# suspects_identified         0
# dtype: int64

# %%
processed_data_new[processed_data_new.isnull().any(axis=1)].head()
# Out:
#       index  city_or_county  n_killed  n_injured  congressional_district  \
# 58     1933  Henrico County         1          0                     NaN
# 529   20588         Norfolk         1          0                     NaN
# 611   23491           Axton         1          0                     5.0
# 1189  48193         Roanoke         0          0                     NaN
# 1314  53727      Chesapeake         1          0                     NaN
#
#       latitude  longitude  state_house_district  state_senate_district  month  \
# 58         NaN        NaN                   NaN                    NaN      1
# 529        NaN        NaN                   NaN                    NaN      6
# 611    36.6625   -79.7336                   NaN                   20.0      6
# 1189       NaN        NaN                   NaN                    NaN     11
# 1314       NaN        NaN                   NaN                    NaN      1
#
#       year  child_participants  teen_participants  adult_participants  \
# 58    2014                   0                  0                   2
# 529   2014                   0                  0                   2
# 611   2014                   0                  0                   1
# 1189  2014                   0                  0                   2
# 1314  2015                   0                  0                   1
#
#       male_participants  female_participants  arrested_participants  \
# 58                    2                    0                      1
# 529                   2                    0                      1
# 611                   1                    0                      0
# 1189                  2                    0                      2
# 1314                  1                    0                      0
#
#       unharmed_participants  victims_involved  suspects_identified
# 58                        0                 1                    1
# 529                       0                 0                    2
# 611                       0                 1                    0
# 1189                      0                 0                    2
# 1314                      0                 1                    0

# %%
#it does not make sense to put median values in latitude and longitude /location specific fields 
# and since the rows are quite few as compared to our datasize, we can drop these rows with null values.

processed_data_new = processed_data_new.dropna(subset=["latitude", "longitude", 
                                                       "congressional_district", 
                                                       "state_senate_district",
                                                       "state_house_district"])
processed_data_new.shape
# Out:
# (5653, 20)

# %%
#splitting data into train and test for analysis
train_set, test_set = train_test_split(processed_data_new, test_size=0.2, random_state=42)

print("train: ",train_set.shape)
print("test: ",test_set.shape)
# Out:
# train:  (4522, 20)
# test:  (1131, 20)

# %%
from future_encoders import ColumnTransformer
from future_encoders import OneHotEncoder

train_set_num = train_set.drop('city_or_county', axis=1)
train_set_cat = train_set[['city_or_county']]

num_pipeline = Pipeline([
        ('imputer', Imputer(strategy="median")),
        ('std_scaler', StandardScaler()),
    ])

num_attribs = list(train_set_num)
cat_attribs = ["city_or_county"]

full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        #("cat", OneHotEncoder(), cat_attribs),
    ])

X_train = full_pipeline.fit_transform(train_set)
X_train
# Out:
# array([[ 0.34962696, -0.47515657, -0.82223768, ...,  0.69130362,
#         -1.14082759,  0.26465573],
#        [ 1.2384174 , -0.47515657,  0.54222426, ..., -0.46010521,
#          0.18160829, -0.81449053],
#        [-0.74464653, -0.47515657, -0.82223768, ..., -0.46010521,
#         -1.14082759,  0.26465573],
#        ...,
#        [ 1.48490567, -0.47515657,  0.54222426, ..., -0.46010521,
#          0.18160829, -0.81449053],
#        [ 1.60007994,  1.51250117, -0.82223768, ..., -0.46010521,
#          0.18160829,  0.26465573],
#        [-1.22734965, -0.47515657, -0.82223768, ...,  0.69130362,
#          0.18160829,  0.26465573]])

# %%
test_set_num = test_set.drop('city_or_county', axis=1)
test_set_cat = test_set[['city_or_county']]

X_test = full_pipeline.transform(test_set_num)
X_test
# Out:
# array([[ 0.48814856,  1.51250117, -0.82223768, ..., -0.46010521,
#          0.18160829, -0.81449053],
#        [-1.17571726, -0.47515657,  0.54222426, ..., -0.46010521,
#          0.18160829, -0.81449053],
#        [ 0.49739021, -0.47515657, -0.82223768, ..., -0.46010521,
#         -1.14082759, -0.81449053],
#        ...,
#        [-1.31886706, -0.47515657, -0.82223768, ...,  0.69130362,
#          0.18160829,  0.26465573],
#        [ 0.75709979,  1.51250117, -0.82223768, ..., -0.46010521,
#          0.18160829,  0.26465573],
#        [-1.35602528,  1.51250117, -0.82223768, ...,  0.69130362,
#          0.18160829,  0.26465573]])
